# %%
# Import
import pandas as pd
import requests
import re
import datetime as dt
from datetime import datetime
import pickle
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

def requests_retry_session(
    retries=5,
    backoff_factor=0.3,
    status_forcelist=(500, 502, 504),
    session=None,
):
    session = session or requests.Session()
    retry = Retry(
        total=retries,
        read=retries,
        connect=retries,
        backoff_factor=backoff_factor,
        status_forcelist=status_forcelist,
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

# loading the city code
citycode = pd.read_excel('Book1.xlsx')
citycode = citycode.T
citycode = citycode.reset_index()
citycode = citycode['index']
cityframe = pd.DataFrame(columns=['city', 'code'])
for i in range(0, 438):
    cityframe = cityframe.append({'city': citycode[2 * i], 'code': float(citycode[2 * i + 1])}, ignore_index=True)
cityframe['code'] = round(cityframe['code'])
cityframe['code'] = cityframe['code'].astype('int')
cityframe = cityframe.drop_duplicates(subset='code', keep='first')

#load
with open('mo.txt','rb') as f:
    dout = pickle.load(f)

with open('mi.txt','rb') as f:
    din = pickle.load(f)

# adding new data
lastupdate = list(dout.keys())
lastupdate = [dt.datetime.strptime(d,'%Y%m%d').date() for d in lastupdate]
sday = max(lastupdate)+dt.timedelta(days=1)
eday = dt.date.today()-dt.timedelta(days=1)
nperiod = pd.date_range(start=sday, end=eday)
nperiod = nperiod.strftime('%Y%m%d')

for d in nperiod:
    date = d
    rx_dict = {
        'city_name': re.compile(r'"city_name":"(?P<city_name>.*)","province_name"'),
        'value': re.compile(r'"value":(\d*[.]?\d*)')
    }
    moveout = {}
    movein = {}
    mic = list()
    miv = list()
    moc = list()
    mov = list()

    for i in range(0, cityframe.shape[0]):
        city = cityframe.iloc[i][0]
        code = cityframe.iloc[i][1]
        print(city,i,date)
        ourl = 'http://huiyan.baidu.com/migration/cityrank.jsonp?dt=province&id=%s&type=move_out&date=%s' % (code, date)
        iurl = 'http://huiyan.baidu.com/migration/cityrank.jsonp?dt=province&id=%s&type=move_in&date=%s' % (code, date)
        try:
            ocityrank = requests_retry_session().get(ourl)
            icityrank = requests_retry_session().get(iurl)
        except Exception as x:
            print('It failed :(', x.__class__.__name__)
        else:
            print('It worked')
        otemp = ocityrank.text.split('},')
        itemp = icityrank.text.split('},')
        if len(otemp) > 1:
            ocityr = pd.DataFrame(columns=['city', 'value'])
            for s in otemp:
                oa = re.findall(rx_dict['city_name'], s)
                ob = re.findall(rx_dict['value'], s)
                ocityr = ocityr.append({'city': oa[0].encode('utf-8').decode('unicode-escape'), 'value': ob[0]},
                                     ignore_index=True)
            moc.append(city)
            mov.append(ocityr)
        if len(itemp) > 1:
            icityr = pd.DataFrame(columns=['city', 'value'])
            for s in itemp:
                ia = re.findall(rx_dict['city_name'], s)
                ib = re.findall(rx_dict['value'], s)
                icityr = icityr.append({'city': ia[0].encode('utf-8').decode('unicode-escape'), 'value': ib[0]},
                                     ignore_index=True)
            mic.append(city)
            miv.append(icityr)
    for key, value in zip(moc, mov):
        moveout[key] = value
    moveout = dict(zip(moc, mov))
    dout[d] = moveout
    for key, value in zip(mic, miv):
        movein[key] = value
    movein = dict(zip(mic, miv))
    din[d] = movein              

    with open('mo.txt', 'wb') as f:
        pickle.dump(dout, f)

    with open('mi.txt', 'wb') as f:
        pickle.dump(din, f)
# Out:
# 北京 0 20200226
# It worked
# 天津 1 20200226
# It worked
# 兴安盟 2 20200226
# It worked
# 巢湖 3 20200226
# It worked
# 定安 4 20200226
# It worked
# 屯昌 5 20200226
# It worked
# 澄迈 6 20200226
# It worked
# 临高 7 20200226
# It worked
# 海东地区 8 20200226
# It worked
# 香港 9 20200226
# It worked
# 澳门 10 20200226
# It worked
# 昌都 11 20200226
# It worked
# 山南 12 20200226
# It worked
# 日喀则 13 20200226
# It worked
# 那曲 14 20200226
# It worked
# 林芝 15 20200226
# It worked
# 吐鲁番 16 20200226
# It worked
# 铜仁 17 20200226
# It worked
# 毕节 18 20200226
# It worked
# 广西 19 20200226
# It worked
# 内蒙古 20 20200226
# It worked
# 宁夏 21 20200226
# It worked
# 新疆 22 20200226
# It worked
# 西藏 23 20200226
# It worked
# 石家庄 24 20200226
# It worked
# 唐山 25 20200226
# It worked
# 秦皇岛 26 20200226
# It worked
# 邯郸 27 20200226
# It worked
# 邢台 28 20200226
# It worked
# 保定 29 20200226
# It worked
# 张家口 30 20200226
# It worked
# 承德 31 20200226
# It worked
# 沧州 32 20200226
# It worked
# 廊坊 33 20200226
# It worked
# 衡水 34 20200226
# It worked
# 太原 35 20200226
# It worked
# 大同 36 20200226
# It worked
# 阳泉 37 20200226
# It worked
# 长治 38 20200226
# It worked
# 晋城 39 20200226
# It worked
# 朔州 40 20200226
# It worked
# 晋中 41 20200226
# It worked
# 运城 42 20200226
# It worked
# 忻州 43 20200226
# It worked
# 临汾 44 20200226
# It worked
# 吕梁 45 20200226
# It worked
# 呼和浩特 46 20200226
# It worked
# 包头 47 20200226
# It worked
# 乌海 48 20200226
# It worked
# 赤峰 49 20200226
# It worked
# 通辽 50 20200226
# It worked
# 鄂尔多斯 51 20200226
# It worked
# 呼伦贝尔 52 20200226
# It worked
# 巴彦淖尔 53 20200226
# It worked
# 乌兰察布 54 20200226
# It worked
# 沈阳 55 20200226
# It worked
# 大连 56 20200226
# It worked
# 鞍山 57 20200226
# It worked
# 抚顺 58 20200226
# It worked
# 本溪 59 20200226
# It worked
# 丹东 60 20200226
# It worked
# 锦州 61 20200226
# It worked
# 营口 62 20200226
# It worked
# 阜新 63 20200226
# It worked
# 辽阳 64 20200226
# It worked
# 盘锦 65 20200226
# It worked
# 铁岭 66 20200226
# It worked
# 朝阳 67 20200226
# It worked
# 葫芦岛 68 20200226
# It worked
# 长春 69 20200226
# It worked
# 吉林市 70 20200226
# It worked
# 四平 71 20200226
# It worked
# 辽源 72 20200226
# It worked
# 通化 73 20200226
# It worked
# 白山 74 20200226
# It worked
# 松原 75 20200226
# It worked
# 白城 76 20200226
# It worked
# 哈尔滨 77 20200226
# It worked
# 齐齐哈尔 78 20200226
# It worked
# 鸡西 79 20200226
# It worked
# 鹤岗 80 20200226
# It worked
# 双鸭山 81 20200226
# It worked
# 大庆 82 20200226
# It worked
# 伊春 83 20200226
# It worked
# 佳木斯 84 20200226
# It worked
# 七台河 85 20200226
# It worked
# 牡丹江 86 20200226
# It worked
# 黑河 87 20200226
# It worked
# 绥化 88 20200226
# It worked
# 上海 89 20200226
# It worked
# 南京 90 20200226
# It worked
# 无锡 91 20200226
# It worked
# 徐州 92 20200226
# It worked
# 常州 93 20200226
# It worked
# 苏州 94 20200226
# It worked
# 南通 95 20200226
# It worked
# 连云港 96 20200226
# It worked
# 淮安 97 20200226
# It worked
# 盐城 98 20200226
# It worked
# 扬州 99 20200226
# It worked
# 镇江 100 20200226
# It worked
# 泰州 101 20200226
# It worked
# 宿迁 102 20200226
# It worked
# 浙江 103 20200226
# It worked
# 杭州 104 20200226
# It worked
# 宁波 105 20200226
# It worked
# 温州 106 20200226
# It worked
# 嘉兴 107 20200226
# It worked
# 湖州 108 20200226
# It worked
# 绍兴 109 20200226
# It worked
# 金华 110 20200226
# It worked
# 衢州 111 20200226
# It worked
# 舟山 112 20200226
# It worked
# 台州 113 20200226
# It worked
# 丽水 114 20200226
# It worked
# 合肥 115 20200226
# It worked
# 芜湖 116 20200226
# It worked
# 蚌埠 117 20200226
# It worked
# 淮南 118 20200226
# It worked
# 马鞍山 119 20200226
# It worked
# 淮北 120 20200226
# It worked
# 铜陵 121 20200226
# It worked
# 安庆 122 20200226
# It worked
# 黄山 123 20200226
# It worked
# 滁州 124 20200226
# It worked
# 阜阳 125 20200226
# It worked
# 宿州 126 20200226
# It worked
# 六安 127 20200226
# It worked
# 亳州 128 20200226
# It worked
# 池州 129 20200226
# It worked
# 宣城 130 20200226
# It worked
# 福州 131 20200226
# It worked
# 厦门 132 20200226
# It worked
# 莆田 133 20200226
# It worked
# 三明 134 20200226
# It worked
# 泉州 135 20200226
# It worked
# 漳州 136 20200226
# It worked
# 南平 137 20200226
# It worked
# 龙岩 138 20200226
# It worked
# 宁德 139 20200226
# It worked
# 南昌 140 20200226
# It worked
# 景德镇 141 20200226
# It worked
# 萍乡 142 20200226
# It worked
# 九江 143 20200226
# It worked
# 新余 144 20200226
# It worked
# 鹰潭 145 20200226
# It worked
# 赣州 146 20200226
# It worked
# 吉安 147 20200226
# It worked
# 宜春 148 20200226
# It worked
# 抚州 149 20200226
# It worked
# 上饶 150 20200226
# It worked
# 济南 151 20200226
# It worked
# 青岛 152 20200226
# It worked
# 淄博 153 20200226
# It worked
# 枣庄 154 20200226
# It worked
# 东营 155 20200226
# It worked
# 烟台 156 20200226
# It worked
# 潍坊 157 20200226
# It worked
# 济宁 158 20200226
# It worked
# 泰安 159 20200226
# It worked
# 威海 160 20200226
# It worked
# 日照 161 20200226
# It worked
# 临沂 162 20200226
# It worked
# 德州 163 20200226
# It worked
# 聊城 164 20200226
# It worked
# 滨州 165 20200226
# It worked
# 菏泽 166 20200226
# It worked
# 郑州 167 20200226
# It worked
# 开封 168 20200226
# It worked
# 洛阳 169 20200226
# It worked
# 平顶山 170 20200226
# It worked
# 安阳 171 20200226
# It worked
# 鹤壁 172 20200226
# It worked
# 新乡 173 20200226
# It worked
# 焦作 174 20200226
# It worked
# 濮阳 175 20200226
# It worked
# 许昌 176 20200226
# It worked
# 漯河 177 20200226
# It worked
# 三门峡 178 20200226
# It worked
# 南阳 179 20200226
# It worked
# 商丘 180 20200226
# It worked
# 信阳 181 20200226
# It worked
# 周口 182 20200226
# It worked
# 驻马店 183 20200226
# It worked
# 武汉 184 20200226
# It worked
# 黄石 185 20200226
# It worked
# 十堰 186 20200226
# It worked
# 宜昌 187 20200226
# It worked
# 襄阳 188 20200226
# It worked
# 鄂州 189 20200226
# It worked
# 荆门 190 20200226
# It worked
# 孝感 191 20200226
# It worked
# 荆州 192 20200226
# It worked
# 黄冈 193 20200226
# It worked
# 咸宁 194 20200226
# It worked
# 随州 195 20200226
# It worked
# 仙桃 196 20200226
# It worked
# 潜江 197 20200226
# It worked
# 天门 198 20200226
# It worked
# 长沙 199 20200226
# It worked
# 株洲 200 20200226
# It worked
# 湘潭 201 20200226
# It worked
# 衡阳 202 20200226
# It worked
# 邵阳 203 20200226
# It worked
# 岳阳 204 20200226
# It worked
# 常德 205 20200226
# It worked
# 张家界 206 20200226
# It worked
# 益阳 207 20200226
# It worked
# 郴州 208 20200226
# It worked
# 永州 209 20200226
# It worked
# 怀化 210 20200226
# It worked
# 娄底 211 20200226
# It worked
# 广州 212 20200226
# It worked
# 韶关 213 20200226
# It worked
# 深圳 214 20200226
# It worked
# 珠海 215 20200226
# It worked
# 汕头 216 20200226
# It worked
# 佛山 217 20200226
# It worked
# 江门 218 20200226
# It worked
# 湛江 219 20200226
# It worked
# 茂名 220 20200226
# It worked
# 肇庆 221 20200226
# It worked
# 惠州 222 20200226
# It worked
# 梅州 223 20200226
# It worked
# 汕尾 224 20200226
# It worked
# 河源 225 20200226
# It worked
# 阳江 226 20200226
# It worked
# 清远 227 20200226
# It worked
# 东莞 228 20200226
# It worked
# 济源 229 20200226
# It worked
# 中山 230 20200226
# It worked
# 潮州 231 20200226
# It worked
# 揭阳 232 20200226
# It worked
# 云浮 233 20200226
# It worked
# 南宁 234 20200226
# It worked
# 柳州 235 20200226
# It worked
# 桂林 236 20200226
# It worked
# 梧州 237 20200226
# It worked
# 北海 238 20200226
# It worked
# 防城港 239 20200226
# It worked
# 钦州 240 20200226
# It worked
# 贵港 241 20200226
# It worked
# 玉林 242 20200226
# It worked
# 百色 243 20200226
# It worked
# 贺州 244 20200226
# It worked
# 河池 245 20200226
# It worked
# 来宾 246 20200226
# It worked
# 崇左 247 20200226
# It worked
# 海口 248 20200226
# It worked
# 三亚 249 20200226
# It worked
# 三亚.1 250 20200226
# It worked
# 五指山 251 20200226
# It worked
# 琼海 252 20200226
# It worked
# 儋州 253 20200226
# It worked
# 文昌 254 20200226
# It worked
# 万宁 255 20200226
# It worked
# 东方 256 20200226
# It worked
# 重庆 257 20200226
# It worked
# 成都 258 20200226
# It worked
# 自贡 259 20200226
# It worked
# 攀枝花 260 20200226
# It worked
# 泸州 261 20200226
# It worked
# 德阳 262 20200226
# It worked
# 绵阳 263 20200226
# It worked
# 广元 264 20200226
# It worked
# 遂宁 265 20200226
# It worked
# 内江 266 20200226
# It worked
# 乐山 267 20200226
# It worked
# 南充 268 20200226
# It worked
# 眉山 269 20200226
# It worked
# 宜宾 270 20200226
# It worked
# 广安 271 20200226
# It worked
# 达州 272 20200226
# It worked
# 雅安 273 20200226
# It worked
# 巴中 274 20200226
# It worked
# 资阳 275 20200226
# It worked
# 贵阳 276 20200226
# It worked
# 六盘水 277 20200226
# It worked
# 遵义 278 20200226
# It worked
# 安顺 279 20200226
# It worked
# 昆明 280 20200226
# It worked
# 曲靖 281 20200226
# It worked
# 玉溪 282 20200226
# It worked
# 保山 283 20200226
# It worked
# 昭通 284 20200226
# It worked
# 丽江 285 20200226
# It worked
# 临沧 286 20200226
# It worked
# 普洱 287 20200226
# It worked
# 拉萨 288 20200226
# It worked
# 西安 289 20200226
# It worked
# 铜川 290 20200226
# It worked
# 宝鸡 291 20200226
# It worked
# 咸阳 292 20200226
# It worked
# 渭南 293 20200226
# It worked
# 延安 294 20200226
# It worked
# 汉中 295 20200226
# It worked
# 榆林 296 20200226
# It worked
# 安康 297 20200226
# It worked
# 商洛 298 20200226
# It worked
# 兰州 299 20200226
# It worked
# 嘉峪关 300 20200226
# It worked
# 金昌 301 20200226
# It worked
# 白银 302 20200226
# It worked
# 天水 303 20200226
# It worked
# 武威 304 20200226
# It worked
# 张掖 305 20200226
# It worked
# 平凉 306 20200226
# It worked
# 酒泉 307 20200226
# It worked
# 庆阳 308 20200226
# It worked
# 定西 309 20200226
# It worked
# 陇南 310 20200226
# It worked
# 西宁 311 20200226
# It worked
# 银川 312 20200226
# It worked
# 石嘴山 313 20200226
# It worked
# 吴忠 314 20200226
# It worked
# 固原 315 20200226
# It worked
# 中卫 316 20200226
# It worked
# 乌鲁木齐 317 20200226
# It worked
# 克拉玛依 318 20200226
# It worked
# 石河子 319 20200226
# It worked
# 阿拉尔 320 20200226
# It worked
# 图木舒克 321 20200226
# It worked
# 五家渠 322 20200226
# It worked
# 北屯 323 20200226
# It worked
# 铁门关 324 20200226
# It worked
# 双河 325 20200226
# It worked
# 可克达拉 326 20200226
# It worked
# 昆玉 327 20200226
# It worked
# 恩施 328 20200226
# It worked
# 延边 329 20200226
# It worked
# 神农架地区 330 20200226
# It worked
# 湘西州 331 20200226
# It worked
# 大兴安岭地区 332 20200226
# It worked
# 白沙县 333 20200226
# It worked
# 昌江黎族自治县 334 20200226
# It worked
# 乐东黎族自治县 335 20200226
# It worked
# 陵水黎族自治县 336 20200226
# It worked
# 保亭黎族苗族自治县 337 20200226
# It worked
# 琼中黎族苗族自治县 338 20200226
# It worked
# 阿坝州 339 20200226
# It worked
# 甘孜州 340 20200226
# It worked
# 凉山州 341 20200226
# It worked
# 黔西南布依族苗族自治州 342 20200226
# It worked
# 黔东南苗族侗族自治州 343 20200226
# It worked
# 黔南布依族苗族自治州 344 20200226
# It worked
# 楚雄州 345 20200226
# It worked
# 红河州 346 20200226
# It worked
# 文山 347 20200226
# It worked
# 西双版纳傣族自治州 348 20200226
# It worked
# 大理州 349 20200226
# It worked
# 德宏州 350 20200226
# It worked
# 怒江州 351 20200226
# It worked
# 迪庆州 352 20200226
# It worked
# 阿里地区 353 20200226
# It worked
# 临夏州 354 20200226
# It worked
# 甘南州 355 20200226
# It worked
# 海北州 356 20200226
# It worked
# 黄南州 357 20200226
# It worked
# 海南州 358 20200226
# It worked
# 果洛州 359 20200226
# It worked
# 玉树州 360 20200226
# It worked
# 海西州 361 20200226
# It worked
# 昌吉州 362 20200226
# It worked
# 博尔塔拉州 363 20200226
# It worked
# 巴音郭楞蒙古自治州 364 20200226
# It worked
# 哈密 365 20200226
# It worked
# 阿克苏地区 366 20200226
# It worked
# 克孜勒苏州 367 20200226
# It worked
# 伊犁州 368 20200226
# It worked
# 喀什地区 369 20200226
# It worked
# 和田地区 370 20200226
# It worked
# 塔城地区 371 20200226
# It worked
# 阿勒泰地区 372 20200226
# It worked
# 锡林郭勒盟 373 20200226
# It worked
# 阿拉善盟 374 20200226
# It worked
# 安徽 375 20200226
# It worked
# 福建 376 20200226
# It worked
# 甘肃 377 20200226
# It worked
# 广东 378 20200226
# It worked
# 贵州 379 20200226
# It worked
# 海南 380 20200226
# It worked
# 河北 381 20200226
# It worked
# 黑龙江 382 20200226
# It worked
# 河南 383 20200226
# It worked
# 湖北 384 20200226
# It worked
# 湖南 385 20200226
# It worked
# 江苏 386 20200226
# It worked
# 江西 387 20200226
# It worked
# 吉林 388 20200226
# It worked
# 辽宁 389 20200226
# It worked
# 青海 390 20200226
# It worked
# 山东 391 20200226
# It worked
# 山西 392 20200226
# It worked
# 陕西 393 20200226
# It worked
# 四川 394 20200226
# It worked
# 云南 395 20200226
# It worked
# 北京 0 20200227
# It worked
# 天津 1 20200227
# It worked
# 兴安盟 2 20200227
# It worked
# 巢湖 3 20200227
# It worked
# 定安 4 20200227
# It worked
# 屯昌 5 20200227
# It worked
# 澄迈 6 20200227
# It worked
# 临高 7 20200227
# It worked
# 海东地区 8 20200227
# It worked
# 香港 9 20200227
# It worked
# 澳门 10 20200227
# It worked
# 昌都 11 20200227
# It worked
# 山南 12 20200227
# It worked
# 日喀则 13 20200227
# It worked
# 那曲 14 20200227
# It worked
# 林芝 15 20200227
# It worked
# 吐鲁番 16 20200227
# It worked
# 铜仁 17 20200227
# It worked
# 毕节 18 20200227
# It worked
# 广西 19 20200227
# It worked
# 内蒙古 20 20200227
# It worked
# 宁夏 21 20200227
# It worked
# 新疆 22 20200227
# It worked
# 西藏 23 20200227
# It worked
# 石家庄 24 20200227
# It worked
# 唐山 25 20200227
# It worked
# 秦皇岛 26 20200227
# It worked
# 邯郸 27 20200227
# It worked
# 邢台 28 20200227
# It worked
# 保定 29 20200227
# It worked
# 张家口 30 20200227
# It worked
# 承德 31 20200227
# It worked
# 沧州 32 20200227
# It worked
# 廊坊 33 20200227
# It worked
# 衡水 34 20200227
# It worked
# 太原 35 20200227
# It worked
# 大同 36 20200227
# It worked
# 阳泉 37 20200227
# It worked
# 长治 38 20200227
# It worked
# 晋城 39 20200227
# It worked
# 朔州 40 20200227
# It worked
# 晋中 41 20200227
# It worked
# 运城 42 20200227
# It worked
# 忻州 43 20200227
# It worked
# 临汾 44 20200227
# It worked
# 吕梁 45 20200227
# It worked
# 呼和浩特 46 20200227
# It worked
# 包头 47 20200227
# It worked
# 乌海 48 20200227
# It worked
# 赤峰 49 20200227
# It worked
# 通辽 50 20200227
# It worked
# 鄂尔多斯 51 20200227
# It worked
# 呼伦贝尔 52 20200227
# It worked
# 巴彦淖尔 53 20200227
# It worked
# 乌兰察布 54 20200227
# It worked
# 沈阳 55 20200227
# It worked
# 大连 56 20200227
# It worked
# 鞍山 57 20200227
# It worked
# 抚顺 58 20200227
# It worked
# 本溪 59 20200227
# It worked
# 丹东 60 20200227
# It worked
# 锦州 61 20200227
# It worked
# 营口 62 20200227
# It worked
# 阜新 63 20200227
# It worked
# 辽阳 64 20200227
# It worked
# 盘锦 65 20200227
# It worked
# 铁岭 66 20200227
# It worked
# 朝阳 67 20200227
# It worked
# 葫芦岛 68 20200227
# It worked
# 长春 69 20200227
# It worked
# 吉林市 70 20200227
# It worked
# 四平 71 20200227
# It worked
# 辽源 72 20200227
# It worked
# 通化 73 20200227
# It worked
# 白山 74 20200227
# It worked
# 松原 75 20200227
# It worked
# 白城 76 20200227
# It worked
# 哈尔滨 77 20200227
# It worked
# 齐齐哈尔 78 20200227
# It worked
# 鸡西 79 20200227
# It worked
# 鹤岗 80 20200227
# It worked
# 双鸭山 81 20200227
# It worked
# 大庆 82 20200227
# It worked
# 伊春 83 20200227
# It worked
# 佳木斯 84 20200227
# It worked
# 七台河 85 20200227
# It worked
# 牡丹江 86 20200227
# It worked
# 黑河 87 20200227
# It worked
# 绥化 88 20200227
# It worked
# 上海 89 20200227
# It worked
# 南京 90 20200227
# It worked
# 无锡 91 20200227
# It worked
# 徐州 92 20200227
# It worked
# 常州 93 20200227
# It worked
# 苏州 94 20200227
# It worked
# 南通 95 20200227
# It worked
# 连云港 96 20200227
# It worked
# 淮安 97 20200227
# It worked
# 盐城 98 20200227
# It worked
# 扬州 99 20200227
# It worked
# 镇江 100 20200227
# It worked
# 泰州 101 20200227
# It worked
# 宿迁 102 20200227
# It worked
# 浙江 103 20200227
# It worked
# 杭州 104 20200227
# It worked
# 宁波 105 20200227
# It worked
# 温州 106 20200227
# It worked
# 嘉兴 107 20200227
# It worked
# 湖州 108 20200227
# It worked
# 绍兴 109 20200227
# It worked
# 金华 110 20200227
# It worked
# 衢州 111 20200227
# It worked
# 舟山 112 20200227
# It worked
# 台州 113 20200227
# It worked
# 丽水 114 20200227
# It worked
# 合肥 115 20200227
# It worked
# 芜湖 116 20200227
# It worked
# 蚌埠 117 20200227
# It worked
# 淮南 118 20200227
# It worked
# 马鞍山 119 20200227
# It worked
# 淮北 120 20200227
# It worked
# 铜陵 121 20200227
# It worked
# 安庆 122 20200227
# It worked
# 黄山 123 20200227
# It worked
# 滁州 124 20200227
# It worked
# 阜阳 125 20200227
# It worked
# 宿州 126 20200227
# It worked
# 六安 127 20200227
# It worked
# 亳州 128 20200227
# It worked
# 池州 129 20200227
# It worked
# 宣城 130 20200227
# It worked
# 福州 131 20200227
# It worked
# 厦门 132 20200227
# It worked
# 莆田 133 20200227
# It worked
# 三明 134 20200227
# It worked
# 泉州 135 20200227
# It worked
# 漳州 136 20200227
# It worked
# 南平 137 20200227
# It worked
# 龙岩 138 20200227
# It worked
# 宁德 139 20200227
# It worked
# 南昌 140 20200227
# It worked
# 景德镇 141 20200227
# It worked
# 萍乡 142 20200227
# It worked
# 九江 143 20200227
# It worked
# 新余 144 20200227
# It worked
# 鹰潭 145 20200227
# It worked
# 赣州 146 20200227
# It worked
# 吉安 147 20200227
# It worked
# 宜春 148 20200227
# It worked
# 抚州 149 20200227
# It worked
# 上饶 150 20200227
# It worked
# 济南 151 20200227
# It worked
# 青岛 152 20200227
# It worked
# 淄博 153 20200227
# It worked
# 枣庄 154 20200227
# It worked
# 东营 155 20200227
# It worked
# 烟台 156 20200227
# It worked
# 潍坊 157 20200227
# It worked
# 济宁 158 20200227
# It worked
# 泰安 159 20200227
# It worked
# 威海 160 20200227
# It worked
# 日照 161 20200227
# It worked
# 临沂 162 20200227
# It worked
# 德州 163 20200227
# It worked
# 聊城 164 20200227
# It worked
# 滨州 165 20200227
# It worked
# 菏泽 166 20200227
# It worked
# 郑州 167 20200227
# It worked
# 开封 168 20200227
# It worked
# 洛阳 169 20200227
# It worked
# 平顶山 170 20200227
# It worked
# 安阳 171 20200227
# It worked
# 鹤壁 172 20200227
# It worked
# 新乡 173 20200227
# It worked
# 焦作 174 20200227
# It worked
# 濮阳 175 20200227
# It worked
# 许昌 176 20200227
# It worked
# 漯河 177 20200227
# It worked
# 三门峡 178 20200227
# It worked
# 南阳 179 20200227
# It worked
# 商丘 180 20200227
# It worked
# 信阳 181 20200227
# It worked
# 周口 182 20200227
# It worked
# 驻马店 183 20200227
# It worked
# 武汉 184 20200227
# It worked
# 黄石 185 20200227
# It worked
# 十堰 186 20200227
# It worked
# 宜昌 187 20200227
# It worked
# 襄阳 188 20200227
# It worked
# 鄂州 189 20200227
# It worked
# 荆门 190 20200227
# It worked
# 孝感 191 20200227
# It worked
# 荆州 192 20200227
# It worked
# 黄冈 193 20200227
# It worked
# 咸宁 194 20200227
# It worked
# 随州 195 20200227
# It worked
# 仙桃 196 20200227
# It worked
# 潜江 197 20200227
# It worked
# 天门 198 20200227
# It worked
# 长沙 199 20200227
# It worked
# 株洲 200 20200227
# It worked
# 湘潭 201 20200227
# It worked
# 衡阳 202 20200227
# It worked
# 邵阳 203 20200227
# It worked
# 岳阳 204 20200227
# It worked
# 常德 205 20200227
# It worked
# 张家界 206 20200227
# It worked
# 益阳 207 20200227
# It worked
# 郴州 208 20200227
# It worked
# 永州 209 20200227
# It worked
# 怀化 210 20200227
# It worked
# 娄底 211 20200227
# It worked
# 广州 212 20200227
# It worked
# 韶关 213 20200227
# It worked
# 深圳 214 20200227
# It worked
# 珠海 215 20200227
# It worked
# 汕头 216 20200227
# It worked
# 佛山 217 20200227
# It worked
# 江门 218 20200227
# It worked
# 湛江 219 20200227
# It worked
# 茂名 220 20200227
# It worked
# 肇庆 221 20200227
# It worked
# 惠州 222 20200227
# It worked
# 梅州 223 20200227
# It worked
# 汕尾 224 20200227
# It worked
# 河源 225 20200227
# It worked
# 阳江 226 20200227
# It worked
# 清远 227 20200227
# It worked
# 东莞 228 20200227
# It worked
# 济源 229 20200227
# It worked
# 中山 230 20200227
# It worked
# 潮州 231 20200227
# It worked
# 揭阳 232 20200227
# It worked
# 云浮 233 20200227
# It worked
# 南宁 234 20200227
# It worked
# 柳州 235 20200227
# It worked
# 桂林 236 20200227
# It worked
# 梧州 237 20200227
# It worked
# 北海 238 20200227
# It worked
# 防城港 239 20200227
# It worked
# 钦州 240 20200227
# It worked
# 贵港 241 20200227
# It worked
# 玉林 242 20200227
# It worked
# 百色 243 20200227
# It worked
# 贺州 244 20200227
# It worked
# 河池 245 20200227
# It worked
# 来宾 246 20200227
# It worked
# 崇左 247 20200227
# It worked
# 海口 248 20200227
# It worked
# 三亚 249 20200227
# It worked
# 三亚.1 250 20200227
# It worked
# 五指山 251 20200227
# It worked
# 琼海 252 20200227
# It worked
# 儋州 253 20200227
# It worked
# 文昌 254 20200227
# It worked
# 万宁 255 20200227
# It worked
# 东方 256 20200227
# It worked
# 重庆 257 20200227
# It worked
# 成都 258 20200227
# It worked
# 自贡 259 20200227
# It worked
# 攀枝花 260 20200227
# It worked
# 泸州 261 20200227
# It worked
# 德阳 262 20200227
# It worked
# 绵阳 263 20200227
# It worked
# 广元 264 20200227
# It worked
# 遂宁 265 20200227
# It worked
# 内江 266 20200227
# It worked
# 乐山 267 20200227
# It worked
# 南充 268 20200227
# It worked
# 眉山 269 20200227
# It worked
# 宜宾 270 20200227
# It worked
# 广安 271 20200227
# It worked
# 达州 272 20200227
# It worked
# 雅安 273 20200227
# It worked
# 巴中 274 20200227
# It worked
# 资阳 275 20200227
# It worked
# 贵阳 276 20200227
# It worked
# 六盘水 277 20200227
# It worked
# 遵义 278 20200227
# It worked
# 安顺 279 20200227
# It worked
# 昆明 280 20200227
# It worked
# 曲靖 281 20200227
# It worked
# 玉溪 282 20200227
# It worked
# 保山 283 20200227
# It worked
# 昭通 284 20200227
# It worked
# 丽江 285 20200227
# It worked
# 临沧 286 20200227
# It worked
# 普洱 287 20200227
# It worked
# 拉萨 288 20200227
# It worked
# 西安 289 20200227
# It worked
# 铜川 290 20200227
# It worked
# 宝鸡 291 20200227
# It worked
# 咸阳 292 20200227
# It worked
# 渭南 293 20200227
# It worked
# 延安 294 20200227
# It worked
# 汉中 295 20200227
# It worked
# 榆林 296 20200227
# It worked
# 安康 297 20200227
# It worked
# 商洛 298 20200227
# It worked
# 兰州 299 20200227
# It worked
# 嘉峪关 300 20200227
# It worked
# 金昌 301 20200227
# It worked
# 白银 302 20200227
# It worked
# 天水 303 20200227
# It worked
# 武威 304 20200227
# It worked
# 张掖 305 20200227
# It worked
# 平凉 306 20200227
# It worked
# 酒泉 307 20200227
# It worked
# 庆阳 308 20200227
# It worked
# 定西 309 20200227
# It worked
# 陇南 310 20200227
# It worked
# 西宁 311 20200227
# It worked
# 银川 312 20200227
# It worked
# 石嘴山 313 20200227
# It worked
# 吴忠 314 20200227
# It worked
# 固原 315 20200227
# It worked
# 中卫 316 20200227
# It worked
# 乌鲁木齐 317 20200227
# It worked
# 克拉玛依 318 20200227
# It worked
# 石河子 319 20200227
# It worked
# 阿拉尔 320 20200227
# It worked
# 图木舒克 321 20200227
# It worked
# 五家渠 322 20200227
# It worked
# 北屯 323 20200227
# It worked
# 铁门关 324 20200227
# It worked
# 双河 325 20200227
# It worked
# 可克达拉 326 20200227
# It worked
# 昆玉 327 20200227
# It worked
# 恩施 328 20200227
# It worked
# 延边 329 20200227
# It worked
# 神农架地区 330 20200227
# It worked
# 湘西州 331 20200227
# It worked
# 大兴安岭地区 332 20200227
# It worked
# 白沙县 333 20200227
# It worked
# 昌江黎族自治县 334 20200227
# It worked
# 乐东黎族自治县 335 20200227
# It worked
# 陵水黎族自治县 336 20200227
# It worked
# 保亭黎族苗族自治县 337 20200227
# It worked
# 琼中黎族苗族自治县 338 20200227
# It worked
# 阿坝州 339 20200227
# It worked
# 甘孜州 340 20200227
# It worked
# 凉山州 341 20200227
# It worked
# 黔西南布依族苗族自治州 342 20200227
# It worked
# 黔东南苗族侗族自治州 343 20200227
# It worked
# 黔南布依族苗族自治州 344 20200227
# It worked
# 楚雄州 345 20200227
# It worked
# 红河州 346 20200227
# It worked
# 文山 347 20200227
# It worked
# 西双版纳傣族自治州 348 20200227
# It worked
# 大理州 349 20200227
# It worked
# 德宏州 350 20200227
# It worked
# 怒江州 351 20200227
# It worked
# 迪庆州 352 20200227
# It worked
# 阿里地区 353 20200227
# It worked
# 临夏州 354 20200227
# It worked
# 甘南州 355 20200227
# It worked
# 海北州 356 20200227
# It worked
# 黄南州 357 20200227
# It worked
# 海南州 358 20200227
# It worked
# 果洛州 359 20200227
# It worked
# 玉树州 360 20200227
# It worked
# 海西州 361 20200227
# It worked
# 昌吉州 362 20200227
# It worked
# 博尔塔拉州 363 20200227
# It worked
# 巴音郭楞蒙古自治州 364 20200227
# It worked
# 哈密 365 20200227
# It worked
# 阿克苏地区 366 20200227
# It worked
# 克孜勒苏州 367 20200227
# It worked
# 伊犁州 368 20200227
# It worked
# 喀什地区 369 20200227
# It worked
# 和田地区 370 20200227
# It worked
# 塔城地区 371 20200227
# It worked
# 阿勒泰地区 372 20200227
# It worked
# 锡林郭勒盟 373 20200227
# It worked
# 阿拉善盟 374 20200227
# It worked
# 安徽 375 20200227
# It worked
# 福建 376 20200227
# It worked
# 甘肃 377 20200227
# It worked
# 广东 378 20200227
# It worked
# 贵州 379 20200227
# It worked
# 海南 380 20200227
# It worked
# 河北 381 20200227
# It worked
# 黑龙江 382 20200227
# It worked
# 河南 383 20200227
# It worked
# 湖北 384 20200227
# It worked
# 湖南 385 20200227
# It worked
# 江苏 386 20200227
# It worked
# 江西 387 20200227
# It worked
# 吉林 388 20200227
# It worked
# 辽宁 389 20200227
# It worked
# 青海 390 20200227
# It worked
# 山东 391 20200227
# It worked
# 山西 392 20200227
# It worked
# 陕西 393 20200227
# It worked
# 四川 394 20200227
# It worked
# 云南 395 20200227
# It worked

# %%
import copy

# Fixing
def Diff(li1,li2):
    return(list(set(li1) - set(li2)))
day1 = dt.date(2020, 1, 1)
dayend = list(din.keys())[-1]
dayend = datetime.strptime(dayend,'%Y%m%d')
period = pd.date_range(start=day1, end=dayend)
period = period.strftime('%Y%m%d')

tempc = list(cityframe['city'])
oli = list()
ili = list()

dinli = []
doutli = []
ddinli = []
ddoutli = []

for key in din.items():
    dinli.append(list(key[1]))
    doutli.append(list(key[1]))

for i in range(0,len(period)):
    ddinli.append(Diff(tempc,dinli[i]))
    ddoutli.append(Diff(tempc,doutli[i]))

ddinli2 = copy.deepcopy(ddinli)
ddoutli2 = copy.deepcopy(ddoutli)
tries = 50
for i in range(0,len(period)):
    date = period[i]
    rx_dict = {
        'city_name': re.compile(r'"city_name":"(?P<city_name>.*)","province_name"'),
        'value': re.compile(r'"value":(\d*[.]?\d*)'),
        'err_msg': re.compile(r'"errmsg":"(?P<err_msg>.*)",')
    }
    if len(ddoutli[i]) > 0:
        olist = ddoutli[i]
        for j in range(0, len(olist)):
            city = olist[j]
            code = cityframe[cityframe['city']==city]['code']
            ourl = 'http://huiyan.baidu.com/migration/cityrank.jsonp?dt=province&id=%s&type=move_out&date=%s' % (code, date)
            ocond = 0
            oloop = 1
            while ocond == 0 and oloop <= tries:
                print(city, i, date, "oloop=",oloop)
                try:
                    ocityrank = requests_retry_session().get(ourl)
                except Exception as x:
                    print('It failed :(', x.__class__.__name__)
                else:
                    print('It worked')
                otemp = ocityrank.text.split('},')
                err_msg = re.findall(rx_dict['err_msg'],otemp[0])
                if err_msg[0] == 'id is not valid':
                    ddoutli2[i].remove(city)
                    oloop = tries+1
                elif len(otemp) > 2:
                    ocityr = pd.DataFrame(columns=['city', 'value'])
                    for s in otemp:
                        oa = re.findall(rx_dict['city_name'], s)
                        ob = re.findall(rx_dict['value'], s)
                        ocityr = ocityr.append({'city': oa[0].encode('utf-8').decode('unicode-escape'), 'value': ob[0]},
                                             ignore_index=True)
                    dout[date][city] = ocityr
                    ocond = 1
                else:
                    ocond = 0
                    oloop = oloop+1
            if oloop >= tries:
                oli.append([date,city,err_msg])



    if len(ddinli[i]) > 0:
        ilist = ddinli[i]
        for j in range(0, len(ilist)):
            city = ilist[j]
            code = cityframe[cityframe['city']==city]['code']
            iurl = 'http://huiyan.baidu.com/migration/cityrank.jsonp?dt=province&id=%s&type=move_in&date=%s' % (code, date)
            icond = 0
            iloop = 1
            while icond == 0 and iloop <= tries:
                print(city, i, date, "iloop=",iloop)
                try:
                    icityrank = requests_retry_session().get(iurl)
                except Exception as x:
                    print('It failed :(', x.__class__.__name__)
                else:
                    print('It worked')
                itemp = icityrank.text.split('},')
                err_msg = re.findall(rx_dict['err_msg'],otemp[0])
                if err_msg[0] == 'id is not valid':
                    ddinli2[i].remove(city)
                    iloop = tries+1
                elif len(itemp) > 2:
                    icityr = pd.DataFrame(columns=['city', 'value'])
                    for s in itemp:
                        ia = re.findall(rx_dict['city_name'], s)
                        ib = re.findall(rx_dict['value'], s)
                        icityr = icityr.append({'city': ia[0].encode('utf-8').decode('unicode-escape'), 'value': ib[0]},
                                             ignore_index=True)
                    din[date][city] = icityr
                    icond = 1
                else:
                    icond = 0
                    iloop = iloop + 1
                if iloop >= tries:
                    ili.append([date, city, err_msg])
# Out:
# 巢湖 0 20200101 oloop= 1
# It worked
# 孝感 0 20200101 oloop= 1
# It worked
# 柳州 0 20200101 oloop= 1
# It worked
# 桂林 0 20200101 oloop= 1
# It worked
# 黄冈 0 20200101 oloop= 1
# It worked
# 宜宾 0 20200101 oloop= 1
# It worked
# 襄阳 0 20200101 oloop= 1
# It worked
# 新乡 0 20200101 oloop= 1
# It worked
# 西宁 0 20200101 oloop= 1
# It worked
# 巢湖 0 20200101 iloop= 1
# It worked
# 孝感 0 20200101 iloop= 1
# It worked
# 柳州 0 20200101 iloop= 1
# It worked
# 桂林 0 20200101 iloop= 1
# It worked
# 黄冈 0 20200101 iloop= 1
# It worked
# 宜宾 0 20200101 iloop= 1
# It worked
# 襄阳 0 20200101 iloop= 1
# It worked
# 新乡 0 20200101 iloop= 1
# It worked
# 西宁 0 20200101 iloop= 1
# It worked
# 宜宾 1 20200102 oloop= 1
# It worked
# 巢湖 1 20200102 oloop= 1
# It worked
# 郑州 1 20200102 oloop= 1
# It worked
# 襄阳 1 20200102 oloop= 1
# It worked
# 宜宾 1 20200102 iloop= 1
# It worked
# 巢湖 1 20200102 iloop= 1
# It worked
# 郑州 1 20200102 iloop= 1
# It worked
# 襄阳 1 20200102 iloop= 1
# It worked
# 黄冈 2 20200103 oloop= 1
# It worked
# 襄阳 2 20200103 oloop= 1
# It worked
# 巢湖 2 20200103 oloop= 1
# It worked
# 西宁 2 20200103 oloop= 1
# It worked
# 黄冈 2 20200103 iloop= 1
# It worked
# 襄阳 2 20200103 iloop= 1
# It worked
# 巢湖 2 20200103 iloop= 1
# It worked
# 西宁 2 20200103 iloop= 1
# It worked
# 黄冈 3 20200104 oloop= 1
# It worked
# 巢湖 3 20200104 oloop= 1
# It worked
# 西宁 3 20200104 oloop= 1
# It worked
# 黄冈 3 20200104 iloop= 1
# It worked
# 巢湖 3 20200104 iloop= 1
# It worked
# 西宁 3 20200104 iloop= 1
# It worked
# 巢湖 5 20200106 oloop= 1
# It worked
# 阿拉善盟 5 20200106 oloop= 1
# It worked
# 成都 5 20200106 oloop= 1
# It worked
# 茂名 5 20200106 oloop= 1
# It worked
# 白银 5 20200106 oloop= 1
# It worked
# 肇庆 5 20200106 oloop= 1
# It worked
# 延边 5 20200106 oloop= 1
# It worked
# 佛山 5 20200106 oloop= 1
# It worked
# 黄石 5 20200106 oloop= 1
# It worked
# 梧州 5 20200106 oloop= 1
# It worked
# 天门 5 20200106 oloop= 1
# It worked
# 神农架地区 5 20200106 oloop= 1
# It worked
# 潜江 5 20200106 oloop= 1
# It worked
# 广州 5 20200106 oloop= 1
# It worked
# 南充 5 20200106 oloop= 1
# It worked
# 巢湖 5 20200106 iloop= 1
# It worked
# 阿拉善盟 5 20200106 iloop= 1
# It worked
# 成都 5 20200106 iloop= 1
# It worked
# 茂名 5 20200106 iloop= 1
# It worked
# 白银 5 20200106 iloop= 1
# It worked
# 肇庆 5 20200106 iloop= 1
# It worked
# 延边 5 20200106 iloop= 1
# It worked
# 佛山 5 20200106 iloop= 1
# It worked
# 黄石 5 20200106 iloop= 1
# It worked
# 梧州 5 20200106 iloop= 1
# It worked
# 天门 5 20200106 iloop= 1
# It worked
# 神农架地区 5 20200106 iloop= 1
# It worked
# 潜江 5 20200106 iloop= 1
# It worked
# 广州 5 20200106 iloop= 1
# It worked
# 南充 5 20200106 iloop= 1
# It worked
# 巢湖 6 20200107 oloop= 1
# It worked
# 安庆 6 20200107 oloop= 1
# It worked
# 六安 6 20200107 oloop= 1
# It worked
# 福州 6 20200107 oloop= 1
# It worked
# 保山 6 20200107 oloop= 1
# It worked
# 合肥 6 20200107 oloop= 1
# It worked
# 阜阳 6 20200107 oloop= 1
# It worked
# 丽江 6 20200107 oloop= 1
# It worked
# 莆田 6 20200107 oloop= 1
# It worked
# 临沧 6 20200107 oloop= 1
# It worked
# 厦门 6 20200107 oloop= 1
# It worked
# 拉萨 6 20200107 oloop= 1
# It worked
# 普洱 6 20200107 oloop= 1
# It worked
# 泸州 6 20200107 oloop= 1
# It worked
# 巢湖 6 20200107 iloop= 1
# It worked
# 安庆 6 20200107 iloop= 1
# It worked
# 六安 6 20200107 iloop= 1
# It worked
# 福州 6 20200107 iloop= 1
# It worked
# 保山 6 20200107 iloop= 1
# It worked
# 合肥 6 20200107 iloop= 1
# It worked
# 阜阳 6 20200107 iloop= 1
# It worked
# 丽江 6 20200107 iloop= 1
# It worked
# 莆田 6 20200107 iloop= 1
# It worked
# 临沧 6 20200107 iloop= 1
# It worked
# 厦门 6 20200107 iloop= 1
# It worked
# 拉萨 6 20200107 iloop= 1
# It worked
# 普洱 6 20200107 iloop= 1
# It worked
# 泸州 6 20200107 iloop= 1
# It worked
# 巢湖 7 20200108 oloop= 1
# It worked
# 六安 7 20200108 oloop= 1
# It worked
# 石家庄 7 20200108 oloop= 1
# It worked
# 莆田 7 20200108 oloop= 1
# It worked
# 郑州 7 20200108 oloop= 1
# It worked
# 巢湖 7 20200108 iloop= 1
# It worked
# 六安 7 20200108 iloop= 1
# It worked
# 石家庄 7 20200108 iloop= 1
# It worked
# 莆田 7 20200108 iloop= 1
# It worked
# 郑州 7 20200108 iloop= 1
# It worked
# 河池 8 20200109 oloop= 1
# It worked
# 巴中 8 20200109 oloop= 1
# It worked
# 广元 8 20200109 oloop= 1
# It worked
# 甘孜州 8 20200109 oloop= 1
# It worked
# 阿坝州 8 20200109 oloop= 1
# It worked
# 达州 8 20200109 oloop= 1
# It worked
# 资阳 8 20200109 oloop= 1
# It worked
# 广安 8 20200109 oloop= 1
# It worked
# 遵义 8 20200109 oloop= 1
# It worked
# 桂林 8 20200109 oloop= 1
# It worked
# 河源 8 20200109 oloop= 1
# It worked
# 果洛州 8 20200109 oloop= 1
# It worked
# 西安 8 20200109 oloop= 1
# It worked
# 贵港 8 20200109 oloop= 1
# It worked
# 安顺 8 20200109 oloop= 1
# It worked
# 德阳 8 20200109 oloop= 1
# It worked
# 成都 8 20200109 oloop= 1
# It worked
# 宝鸡 8 20200109 oloop= 1
# It worked
# 巢湖 8 20200109 oloop= 1
# It worked
# 揭阳 8 20200109 oloop= 1
# It worked
# 河池 8 20200109 iloop= 1
# It worked
# 巴中 8 20200109 iloop= 1
# It worked
# 广元 8 20200109 iloop= 1
# It worked
# 甘孜州 8 20200109 iloop= 1
# It worked
# 阿坝州 8 20200109 iloop= 1
# It worked
# 达州 8 20200109 iloop= 1
# It worked
# 资阳 8 20200109 iloop= 1
# It worked
# 广安 8 20200109 iloop= 1
# It worked
# 遵义 8 20200109 iloop= 1
# It worked
# 桂林 8 20200109 iloop= 1
# It worked
# 河源 8 20200109 iloop= 1
# It worked
# 果洛州 8 20200109 iloop= 1
# It worked
# 西安 8 20200109 iloop= 1
# It worked
# 贵港 8 20200109 iloop= 1
# It worked
# 安顺 8 20200109 iloop= 1
# It worked
# 德阳 8 20200109 iloop= 1
# It worked
# 成都 8 20200109 iloop= 1
# It worked
# 宝鸡 8 20200109 iloop= 1
# It worked
# 巢湖 8 20200109 iloop= 1
# It worked
# 揭阳 8 20200109 iloop= 1
# It worked
# 六安 9 20200110 oloop= 1
# It worked
# 黄冈 9 20200110 oloop= 1
# It worked
# 佛山 9 20200110 oloop= 1
# It worked
# 厦门 9 20200110 oloop= 1
# It worked
# 驻马店 9 20200110 oloop= 1
# It worked
# 信阳 9 20200110 oloop= 1
# It worked
# 韶关 9 20200110 oloop= 1
# It worked
# 平顶山 9 20200110 oloop= 1
# It worked
# 福州 9 20200110 oloop= 1
# It worked
# 合肥 9 20200110 oloop= 1
# It worked
# 汕头 9 20200110 oloop= 1
# It worked
# 郑州 9 20200110 oloop= 1
# It worked
# 柳州 9 20200110 oloop= 1
# It worked
# 阜阳 9 20200110 oloop= 1
# It worked
# 莆田 9 20200110 oloop= 1
# It worked
# 贵港 9 20200110 oloop= 1
# It worked
# 黄石 9 20200110 oloop= 1
# It worked
# 蚌埠 9 20200110 oloop= 1
# It worked
# 商丘 9 20200110 oloop= 1
# It worked
# 巢湖 9 20200110 oloop= 1
# It worked
# 安庆 9 20200110 oloop= 1
# It worked
# 珠海 9 20200110 oloop= 1
# It worked
# 南阳 9 20200110 oloop= 1
# It worked
# 泉州 9 20200110 oloop= 1
# It worked
# 周口 9 20200110 oloop= 1
# It worked
# 三明 9 20200110 oloop= 1
# It worked
# 六安 9 20200110 iloop= 1
# It worked
# 黄冈 9 20200110 iloop= 1
# It worked
# 佛山 9 20200110 iloop= 1
# It worked
# 厦门 9 20200110 iloop= 1
# It worked
# 驻马店 9 20200110 iloop= 1
# It worked
# 信阳 9 20200110 iloop= 1
# It worked
# 韶关 9 20200110 iloop= 1
# It worked
# 平顶山 9 20200110 iloop= 1
# It worked
# 福州 9 20200110 iloop= 1
# It worked
# 合肥 9 20200110 iloop= 1
# It worked
# 汕头 9 20200110 iloop= 1
# It worked
# 郑州 9 20200110 iloop= 1
# It worked
# 柳州 9 20200110 iloop= 1
# It worked
# 阜阳 9 20200110 iloop= 1
# It worked
# 莆田 9 20200110 iloop= 1
# It worked
# 贵港 9 20200110 iloop= 1
# It worked
# 黄石 9 20200110 iloop= 1
# It worked
# 蚌埠 9 20200110 iloop= 1
# It worked
# 商丘 9 20200110 iloop= 1
# It worked
# 巢湖 9 20200110 iloop= 1
# It worked
# 安庆 9 20200110 iloop= 1
# It worked
# 珠海 9 20200110 iloop= 1
# It worked
# 南阳 9 20200110 iloop= 1
# It worked
# 泉州 9 20200110 iloop= 1
# It worked
# 周口 9 20200110 iloop= 1
# It worked
# 三明 9 20200110 iloop= 1
# It worked
# 南宁 10 20200111 oloop= 1
# It worked
# 湛江 10 20200111 oloop= 1
# It worked
# 茂名 10 20200111 oloop= 1
# It worked
# 黄冈 10 20200111 oloop= 1
# It worked
# 佛山 10 20200111 oloop= 1
# It worked
# 驻马店 10 20200111 oloop= 1
# It worked
# 惠州 10 20200111 oloop= 1
# It worked
# 信阳 10 20200111 oloop= 1
# It worked
# 韶关 10 20200111 oloop= 1
# It worked
# 平顶山 10 20200111 oloop= 1
# It worked
# 阳江 10 20200111 oloop= 1
# It worked
# 梅州 10 20200111 oloop= 1
# It worked
# 汕头 10 20200111 oloop= 1
# It worked
# 郑州 10 20200111 oloop= 1
# It worked
# 中山 10 20200111 oloop= 1
# It worked
# 汕尾 10 20200111 oloop= 1
# It worked
# 钦州 10 20200111 oloop= 1
# It worked
# 黄石 10 20200111 oloop= 1
# It worked
# 江门 10 20200111 oloop= 1
# It worked
# 商丘 10 20200111 oloop= 1
# It worked
# 巢湖 10 20200111 oloop= 1
# It worked
# 珠海 10 20200111 oloop= 1
# It worked
# 肇庆 10 20200111 oloop= 1
# It worked
# 清远 10 20200111 oloop= 1
# It worked
# 周口 10 20200111 oloop= 1
# It worked
# 南阳 10 20200111 oloop= 1
# It worked
# 南宁 10 20200111 iloop= 1
# It worked
# 湛江 10 20200111 iloop= 1
# It worked
# 茂名 10 20200111 iloop= 1
# It worked
# 黄冈 10 20200111 iloop= 1
# It worked
# 佛山 10 20200111 iloop= 1
# It worked
# 驻马店 10 20200111 iloop= 1
# It worked
# 惠州 10 20200111 iloop= 1
# It worked
# 信阳 10 20200111 iloop= 1
# It worked
# 韶关 10 20200111 iloop= 1
# It worked
# 平顶山 10 20200111 iloop= 1
# It worked
# 阳江 10 20200111 iloop= 1
# It worked
# 梅州 10 20200111 iloop= 1
# It worked
# 汕头 10 20200111 iloop= 1
# It worked
# 郑州 10 20200111 iloop= 1
# It worked
# 中山 10 20200111 iloop= 1
# It worked
# 汕尾 10 20200111 iloop= 1
# It worked
# 钦州 10 20200111 iloop= 1
# It worked
# 黄石 10 20200111 iloop= 1
# It worked
# 江门 10 20200111 iloop= 1
# It worked
# 商丘 10 20200111 iloop= 1
# It worked
# 巢湖 10 20200111 iloop= 1
# It worked
# 珠海 10 20200111 iloop= 1
# It worked
# 肇庆 10 20200111 iloop= 1
# It worked
# 清远 10 20200111 iloop= 1
# It worked
# 周口 10 20200111 iloop= 1
# It worked
# 南阳 10 20200111 iloop= 1
# It worked
# 巢湖 11 20200112 oloop= 1
# It worked
# 绵阳 11 20200112 oloop= 1
# It worked
# 阿坝州 11 20200112 oloop= 1
# It worked
# 资阳 11 20200112 oloop= 1
# It worked
# 广元 11 20200112 oloop= 1
# It worked
# 珠海 11 20200112 oloop= 1
# It worked
# 梅州 11 20200112 oloop= 1
# It worked
# 三亚.1 11 20200112 oloop= 1
# It worked
# 防城港 11 20200112 oloop= 1
# It worked
# 益阳 11 20200112 oloop= 1
# It worked
# 那曲 11 20200112 oloop= 1
# It worked
# 郑州 11 20200112 oloop= 1
# It worked
# 楚雄州 11 20200112 oloop= 1
# It worked
# 眉山 11 20200112 oloop= 1
# It worked
# 南阳 11 20200112 oloop= 1
# It worked
# 海口 11 20200112 oloop= 1
# It worked
# 烟台 11 20200112 oloop= 1
# It worked
# 贵阳 11 20200112 oloop= 1
# It worked
# 巢湖 11 20200112 iloop= 1
# It worked
# 绵阳 11 20200112 iloop= 1
# It worked
# 阿坝州 11 20200112 iloop= 1
# It worked
# 资阳 11 20200112 iloop= 1
# It worked
# 广元 11 20200112 iloop= 1
# It worked
# 珠海 11 20200112 iloop= 1
# It worked
# 梅州 11 20200112 iloop= 1
# It worked
# 三亚.1 11 20200112 iloop= 1
# It worked
# 防城港 11 20200112 iloop= 1
# It worked
# 益阳 11 20200112 iloop= 1
# It worked
# 那曲 11 20200112 iloop= 1
# It worked
# 郑州 11 20200112 iloop= 1
# It worked
# 楚雄州 11 20200112 iloop= 1
# It worked
# 眉山 11 20200112 iloop= 1
# It worked
# 南阳 11 20200112 iloop= 1
# It worked
# 海口 11 20200112 iloop= 1
# It worked
# 烟台 11 20200112 iloop= 1
# It worked
# 贵阳 11 20200112 iloop= 1
# It worked
# 商丘 12 20200113 oloop= 1
# It worked
# 巢湖 12 20200113 oloop= 1
# It worked
# 湛江 12 20200113 oloop= 1
# It worked
# 广元 12 20200113 oloop= 1
# It worked
# 珠海 12 20200113 oloop= 1
# It worked
# 三亚.1 12 20200113 oloop= 1
# It worked
# 曲靖 12 20200113 oloop= 1
# It worked
# 那曲 12 20200113 oloop= 1
# It worked
# 郑州 12 20200113 oloop= 1
# It worked
# 深圳 12 20200113 oloop= 1
# It worked
# 广州 12 20200113 oloop= 1
# It worked
# 海口 12 20200113 oloop= 1
# It worked
# 商丘 12 20200113 iloop= 1
# It worked
# 巢湖 12 20200113 iloop= 1
# It worked
# 湛江 12 20200113 iloop= 1
# It worked
# 广元 12 20200113 iloop= 1
# It worked
# 珠海 12 20200113 iloop= 1
# It worked
# 三亚.1 12 20200113 iloop= 1
# It worked
# 曲靖 12 20200113 iloop= 1
# It worked
# 那曲 12 20200113 iloop= 1
# It worked
# 郑州 12 20200113 iloop= 1
# It worked
# 深圳 12 20200113 iloop= 1
# It worked
# 广州 12 20200113 iloop= 1
# It worked
# 海口 12 20200113 iloop= 1
# It worked
# 巢湖 13 20200114 oloop= 1
# It worked
# 珠海 13 20200114 oloop= 1
# It worked
# 三亚.1 13 20200114 oloop= 1
# It worked
# 那曲 13 20200114 oloop= 1
# It worked
# 吉安 13 20200114 oloop= 1
# It worked
# 巢湖 13 20200114 iloop= 1
# It worked
# 珠海 13 20200114 iloop= 1
# It worked
# 三亚.1 13 20200114 iloop= 1
# It worked
# 那曲 13 20200114 iloop= 1
# It worked
# 吉安 13 20200114 iloop= 1
# It worked
# 巢湖 14 20200115 oloop= 1
# It worked
# 湛江 14 20200115 oloop= 1
# It worked
# 黄山 14 20200115 oloop= 1
# It worked
# 肇庆 14 20200115 oloop= 1
# It worked
# 汕头 14 20200115 oloop= 1
# It worked
# 保定 14 20200115 oloop= 1
# It worked
# 马鞍山 14 20200115 oloop= 1
# It worked
# 巢湖 14 20200115 iloop= 1
# It worked
# 湛江 14 20200115 iloop= 1
# It worked
# 黄山 14 20200115 iloop= 1
# It worked
# 肇庆 14 20200115 iloop= 1
# It worked
# 汕头 14 20200115 iloop= 1
# It worked
# 保定 14 20200115 iloop= 1
# It worked
# 马鞍山 14 20200115 iloop= 1
# It worked
# 巢湖 15 20200116 oloop= 1
# It worked
# 恩施 15 20200116 oloop= 1
# It worked
# 三亚.1 15 20200116 oloop= 1
# It worked
# 延边 15 20200116 oloop= 1
# It worked
# 西安 15 20200116 oloop= 1
# It worked
# 那曲 15 20200116 oloop= 1
# It worked
# 郑州 15 20200116 oloop= 1
# It worked
# 拉萨 15 20200116 oloop= 1
# It worked
# 巢湖 15 20200116 iloop= 1
# It worked
# 恩施 15 20200116 iloop= 1
# It worked
# 三亚.1 15 20200116 iloop= 1
# It worked
# 延边 15 20200116 iloop= 1
# It worked
# 西安 15 20200116 iloop= 1
# It worked
# 那曲 15 20200116 iloop= 1
# It worked
# 郑州 15 20200116 iloop= 1
# It worked
# 拉萨 15 20200116 iloop= 1
# It worked
# 巢湖 16 20200117 oloop= 1
# It worked
# 三亚.1 16 20200117 oloop= 1
# It worked
# 乌鲁木齐 16 20200117 oloop= 1
# It worked
# 宜宾 16 20200117 oloop= 1
# It worked
# 昆玉 16 20200117 oloop= 1
# It worked
# 楚雄州 16 20200117 oloop= 1
# It worked
# 拉萨 16 20200117 oloop= 1
# It worked
# 广州 16 20200117 oloop= 1
# It worked
# 巢湖 16 20200117 iloop= 1
# It worked
# 三亚.1 16 20200117 iloop= 1
# It worked
# 乌鲁木齐 16 20200117 iloop= 1
# It worked
# 宜宾 16 20200117 iloop= 1
# It worked
# 昆玉 16 20200117 iloop= 1
# It worked
# 楚雄州 16 20200117 iloop= 1
# It worked
# 拉萨 16 20200117 iloop= 1
# It worked
# 广州 16 20200117 iloop= 1
# It worked
# 珠海 17 20200118 oloop= 1
# It worked
# 巢湖 17 20200118 oloop= 1
# It worked
# 楚雄州 17 20200118 oloop= 1
# It worked
# 乌鲁木齐 17 20200118 oloop= 1
# It worked
# 珠海 17 20200118 iloop= 1
# It worked
# 巢湖 17 20200118 iloop= 1
# It worked
# 楚雄州 17 20200118 iloop= 1
# It worked
# 乌鲁木齐 17 20200118 iloop= 1
# It worked
# 南宁 18 20200119 oloop= 1
# It worked
# 巢湖 18 20200119 oloop= 1
# It worked
# 三亚.1 18 20200119 oloop= 1
# It worked
# 佛山 18 20200119 oloop= 1
# It worked
# 三亚 18 20200119 oloop= 1
# It worked
# 深圳 18 20200119 oloop= 1
# It worked
# 南阳 18 20200119 oloop= 1
# It worked
# 南宁 18 20200119 iloop= 1
# It worked
# 巢湖 18 20200119 iloop= 1
# It worked
# 三亚.1 18 20200119 iloop= 1
# It worked
# 佛山 18 20200119 iloop= 1
# It worked
# 三亚 18 20200119 iloop= 1
# It worked
# 深圳 18 20200119 iloop= 1
# It worked
# 南阳 18 20200119 iloop= 1
# It worked
# 常德 19 20200120 oloop= 1
# It worked
# 巢湖 19 20200120 oloop= 1
# It worked
# 阳江 19 20200120 oloop= 1
# It worked
# 遵义 19 20200120 oloop= 1
# It worked
# 乌鲁木齐 19 20200120 oloop= 1
# It worked
# 延边 19 20200120 oloop= 1
# It worked
# 曲靖 19 20200120 oloop= 1
# It worked
# 长沙 19 20200120 oloop= 1
# It worked
# 那曲 19 20200120 oloop= 1
# It worked
# 宜宾 19 20200120 oloop= 1
# It worked
# 襄阳 19 20200120 oloop= 1
# It worked
# 拉萨 19 20200120 oloop= 1
# It worked
# 周口 19 20200120 oloop= 1
# It worked
# 韶关 19 20200120 oloop= 1
# It worked
# 玉溪 19 20200120 oloop= 1
# It worked
# 江门 19 20200120 oloop= 1
# It worked
# 常德 19 20200120 iloop= 1
# It worked
# 巢湖 19 20200120 iloop= 1
# It worked
# 阳江 19 20200120 iloop= 1
# It worked
# 遵义 19 20200120 iloop= 1
# It worked
# 乌鲁木齐 19 20200120 iloop= 1
# It worked
# 延边 19 20200120 iloop= 1
# It worked
# 曲靖 19 20200120 iloop= 1
# It worked
# 长沙 19 20200120 iloop= 1
# It worked
# 那曲 19 20200120 iloop= 1
# It worked
# 宜宾 19 20200120 iloop= 1
# It worked
# 襄阳 19 20200120 iloop= 1
# It worked
# 拉萨 19 20200120 iloop= 1
# It worked
# 周口 19 20200120 iloop= 1
# It worked
# 韶关 19 20200120 iloop= 1
# It worked
# 玉溪 19 20200120 iloop= 1
# It worked
# 江门 19 20200120 iloop= 1
# It worked
# 巢湖 20 20200121 oloop= 1
# It worked
# 汉中 20 20200121 oloop= 1
# It worked
# 阳江 20 20200121 oloop= 1
# It worked
# 恩施 20 20200121 oloop= 1
# It worked
# 三亚.1 20 20200121 oloop= 1
# It worked
# 乌鲁木齐 20 20200121 oloop= 1
# It worked
# 那曲 20 20200121 oloop= 1
# It worked
# 巢湖 20 20200121 iloop= 1
# It worked
# 汉中 20 20200121 iloop= 1
# It worked
# 汉中 20 20200121 iloop= 2
# It worked
# 汉中 20 20200121 iloop= 3
# It worked
# 汉中 20 20200121 iloop= 4
# It worked
# 汉中 20 20200121 iloop= 5
# It worked
# 汉中 20 20200121 iloop= 6
# It worked
# 汉中 20 20200121 iloop= 7
# It worked
# 汉中 20 20200121 iloop= 8
# It worked
# 汉中 20 20200121 iloop= 9
# It worked
# 汉中 20 20200121 iloop= 10
# It worked
# 汉中 20 20200121 iloop= 11
# It worked
# 汉中 20 20200121 iloop= 12
# It worked
# 汉中 20 20200121 iloop= 13
# It worked
# 汉中 20 20200121 iloop= 14
# It worked
# 汉中 20 20200121 iloop= 15
# It worked
# 汉中 20 20200121 iloop= 16
# It worked
# 汉中 20 20200121 iloop= 17
# It worked
# 汉中 20 20200121 iloop= 18
# It worked
# 汉中 20 20200121 iloop= 19
# It worked
# 汉中 20 20200121 iloop= 20
# It worked
# 汉中 20 20200121 iloop= 21
# It worked
# 汉中 20 20200121 iloop= 22
# It worked
# 汉中 20 20200121 iloop= 23
# It worked
# 汉中 20 20200121 iloop= 24
# It worked
# 汉中 20 20200121 iloop= 25
# It worked
# 汉中 20 20200121 iloop= 26
# It worked
# 汉中 20 20200121 iloop= 27
# It worked
# 汉中 20 20200121 iloop= 28
# It worked
# 汉中 20 20200121 iloop= 29
# It worked
# 汉中 20 20200121 iloop= 30
# It worked
# 汉中 20 20200121 iloop= 31
# It worked
# 汉中 20 20200121 iloop= 32
# It worked
# 汉中 20 20200121 iloop= 33
# It worked
# 汉中 20 20200121 iloop= 34
# It worked
# 汉中 20 20200121 iloop= 35
# It worked
# 汉中 20 20200121 iloop= 36
# It worked
# 汉中 20 20200121 iloop= 37
# It worked
# 汉中 20 20200121 iloop= 38
# It worked
# 汉中 20 20200121 iloop= 39
# It worked
# 汉中 20 20200121 iloop= 40
# It worked
# 汉中 20 20200121 iloop= 41
# It worked
# 汉中 20 20200121 iloop= 42
# It worked
# 汉中 20 20200121 iloop= 43
# It worked
# 汉中 20 20200121 iloop= 44
# It worked
# 汉中 20 20200121 iloop= 45
# It worked
# 汉中 20 20200121 iloop= 46
# It worked
# 汉中 20 20200121 iloop= 47
# It worked
# 汉中 20 20200121 iloop= 48
# It worked
# 汉中 20 20200121 iloop= 49
# It worked
# 汉中 20 20200121 iloop= 50
# It worked
# 阳江 20 20200121 iloop= 1
# It worked
# 阳江 20 20200121 iloop= 2
# It worked
# 阳江 20 20200121 iloop= 3
# It worked
# 阳江 20 20200121 iloop= 4
# It worked
# 阳江 20 20200121 iloop= 5
# It worked
# 阳江 20 20200121 iloop= 6
# It worked
# 阳江 20 20200121 iloop= 7
# It worked
# 阳江 20 20200121 iloop= 8
# It worked
# 阳江 20 20200121 iloop= 9
# It worked
# 阳江 20 20200121 iloop= 10
# It worked
# 阳江 20 20200121 iloop= 11
# It worked
# 阳江 20 20200121 iloop= 12
# It worked
# 阳江 20 20200121 iloop= 13
# It worked
# 阳江 20 20200121 iloop= 14
# It worked
# 阳江 20 20200121 iloop= 15
# It worked
# 阳江 20 20200121 iloop= 16
# It worked
# 阳江 20 20200121 iloop= 17
# It worked
# 阳江 20 20200121 iloop= 18
# It worked
# 阳江 20 20200121 iloop= 19
# It worked
# 阳江 20 20200121 iloop= 20
# It worked
# 阳江 20 20200121 iloop= 21
# It worked
# 阳江 20 20200121 iloop= 22
# It worked
# 阳江 20 20200121 iloop= 23
# It worked
# 阳江 20 20200121 iloop= 24
# It worked
# 阳江 20 20200121 iloop= 25
# It worked
# 阳江 20 20200121 iloop= 26
# It worked
# 阳江 20 20200121 iloop= 27
# It worked
# 阳江 20 20200121 iloop= 28
# It worked
# 阳江 20 20200121 iloop= 29
# It worked
# 阳江 20 20200121 iloop= 30
# It worked
# 阳江 20 20200121 iloop= 31
# It worked
# 阳江 20 20200121 iloop= 32
# It worked
# 阳江 20 20200121 iloop= 33
# It worked
# 阳江 20 20200121 iloop= 34
# It worked
# 阳江 20 20200121 iloop= 35
# It worked
# 阳江 20 20200121 iloop= 36
# It worked
# 阳江 20 20200121 iloop= 37
# It worked
# 阳江 20 20200121 iloop= 38
# It worked
# 阳江 20 20200121 iloop= 39
# It worked
# 阳江 20 20200121 iloop= 40
# It worked
# 阳江 20 20200121 iloop= 41
# It worked
# 阳江 20 20200121 iloop= 42
# It worked
# 阳江 20 20200121 iloop= 43
# It worked
# 阳江 20 20200121 iloop= 44
# It worked
# 阳江 20 20200121 iloop= 45
# It worked
# 阳江 20 20200121 iloop= 46
# It worked
# 阳江 20 20200121 iloop= 47
# It worked
# 阳江 20 20200121 iloop= 48
# It worked
# 阳江 20 20200121 iloop= 49
# It worked
# 阳江 20 20200121 iloop= 50
# It worked
# 恩施 20 20200121 iloop= 1
# It worked
# 恩施 20 20200121 iloop= 2
# It worked
# 恩施 20 20200121 iloop= 3
# It worked
# 恩施 20 20200121 iloop= 4
# It worked
# 恩施 20 20200121 iloop= 5
# It worked
# 恩施 20 20200121 iloop= 6
# It worked
# 恩施 20 20200121 iloop= 7
# It worked
# 恩施 20 20200121 iloop= 8
# It worked
# 恩施 20 20200121 iloop= 9
# It worked
# 恩施 20 20200121 iloop= 10
# It worked
# 恩施 20 20200121 iloop= 11
# It worked
# 恩施 20 20200121 iloop= 12
# It worked
# 恩施 20 20200121 iloop= 13
# It worked
# 恩施 20 20200121 iloop= 14
# It worked
# 恩施 20 20200121 iloop= 15
# It worked
# 恩施 20 20200121 iloop= 16
# It worked
# 恩施 20 20200121 iloop= 17
# It worked
# 恩施 20 20200121 iloop= 18
# It worked
# 恩施 20 20200121 iloop= 19
# It worked
# 恩施 20 20200121 iloop= 20
# It worked
# 恩施 20 20200121 iloop= 21
# It worked
# 恩施 20 20200121 iloop= 22
# It worked
# 恩施 20 20200121 iloop= 23
# It worked
# 恩施 20 20200121 iloop= 24
# It worked
# 恩施 20 20200121 iloop= 25
# It worked
# 恩施 20 20200121 iloop= 26
# It worked
# 恩施 20 20200121 iloop= 27
# It worked
# 恩施 20 20200121 iloop= 28
# It worked
# 恩施 20 20200121 iloop= 29
# It worked
# 恩施 20 20200121 iloop= 30
# It worked
# 恩施 20 20200121 iloop= 31
# It worked
# 恩施 20 20200121 iloop= 32
# It worked
# 恩施 20 20200121 iloop= 33
# It worked
# 恩施 20 20200121 iloop= 34
# It worked
# 恩施 20 20200121 iloop= 35
# It worked
# 恩施 20 20200121 iloop= 36
# It worked
# 恩施 20 20200121 iloop= 37
# It worked
# 恩施 20 20200121 iloop= 38
# It worked
# 恩施 20 20200121 iloop= 39
# It worked
# 恩施 20 20200121 iloop= 40
# It worked
# 恩施 20 20200121 iloop= 41
# It worked
# 恩施 20 20200121 iloop= 42
# It worked
# 恩施 20 20200121 iloop= 43
# It worked
# 恩施 20 20200121 iloop= 44
# It worked
# 恩施 20 20200121 iloop= 45
# It worked
# 恩施 20 20200121 iloop= 46
# It worked
# 恩施 20 20200121 iloop= 47
# It worked
# 恩施 20 20200121 iloop= 48
# It worked
# 恩施 20 20200121 iloop= 49
# It worked
# 恩施 20 20200121 iloop= 50
# It worked
# 三亚.1 20 20200121 iloop= 1
# It worked
# 三亚.1 20 20200121 iloop= 2
# It worked
# 三亚.1 20 20200121 iloop= 3
# It worked
# 三亚.1 20 20200121 iloop= 4
# It worked
# 三亚.1 20 20200121 iloop= 5
# It worked
# 三亚.1 20 20200121 iloop= 6
# It worked
# 三亚.1 20 20200121 iloop= 7
# It worked
# 三亚.1 20 20200121 iloop= 8
# It worked
# 三亚.1 20 20200121 iloop= 9
# It worked
# 三亚.1 20 20200121 iloop= 10
# It worked
# 三亚.1 20 20200121 iloop= 11
# It worked
# 三亚.1 20 20200121 iloop= 12
# It worked
# 三亚.1 20 20200121 iloop= 13
# It worked
# 三亚.1 20 20200121 iloop= 14
# It worked
# 三亚.1 20 20200121 iloop= 15
# It worked
# 三亚.1 20 20200121 iloop= 16
# It worked
# 三亚.1 20 20200121 iloop= 17
# It worked
# 三亚.1 20 20200121 iloop= 18
# It worked
# 三亚.1 20 20200121 iloop= 19
# It worked
# 三亚.1 20 20200121 iloop= 20
# It worked
# 三亚.1 20 20200121 iloop= 21
# It worked
# 三亚.1 20 20200121 iloop= 22
# It worked
# 三亚.1 20 20200121 iloop= 23
# It worked
# 三亚.1 20 20200121 iloop= 24
# It worked
# 三亚.1 20 20200121 iloop= 25
# It worked
# 三亚.1 20 20200121 iloop= 26
# It worked
# 三亚.1 20 20200121 iloop= 27
# It worked
# 三亚.1 20 20200121 iloop= 28
# It worked
# 三亚.1 20 20200121 iloop= 29
# It worked
# 三亚.1 20 20200121 iloop= 30
# It worked
# 三亚.1 20 20200121 iloop= 31
# It worked
# 三亚.1 20 20200121 iloop= 32
# It worked
# 三亚.1 20 20200121 iloop= 33
# It worked
# 三亚.1 20 20200121 iloop= 34
# It worked
# 三亚.1 20 20200121 iloop= 35
# It worked
# 三亚.1 20 20200121 iloop= 36
# It worked
# 三亚.1 20 20200121 iloop= 37
# It worked
# 三亚.1 20 20200121 iloop= 38
# It worked
# 三亚.1 20 20200121 iloop= 39
# It worked
# 三亚.1 20 20200121 iloop= 40
# It worked
# 三亚.1 20 20200121 iloop= 41
# It worked
# 三亚.1 20 20200121 iloop= 42
# It worked
# 三亚.1 20 20200121 iloop= 43
# It worked
# 三亚.1 20 20200121 iloop= 44
# It worked
# 三亚.1 20 20200121 iloop= 45
# It worked
# 三亚.1 20 20200121 iloop= 46
# It worked
# 三亚.1 20 20200121 iloop= 47
# It worked
# 三亚.1 20 20200121 iloop= 48
# It worked
# 三亚.1 20 20200121 iloop= 49
# It worked
# 三亚.1 20 20200121 iloop= 50
# It worked
# 乌鲁木齐 20 20200121 iloop= 1
# It worked
# 乌鲁木齐 20 20200121 iloop= 2
# It worked
# 乌鲁木齐 20 20200121 iloop= 3
# It worked
# 乌鲁木齐 20 20200121 iloop= 4
# It worked
# 乌鲁木齐 20 20200121 iloop= 5
# It worked
# 乌鲁木齐 20 20200121 iloop= 6
# It worked
# 乌鲁木齐 20 20200121 iloop= 7
# It worked
# 乌鲁木齐 20 20200121 iloop= 8
# It worked
# 乌鲁木齐 20 20200121 iloop= 9
# It worked
# 乌鲁木齐 20 20200121 iloop= 10
# It worked
# 乌鲁木齐 20 20200121 iloop= 11
# It worked
# 乌鲁木齐 20 20200121 iloop= 12
# It worked
# 乌鲁木齐 20 20200121 iloop= 13
# It worked
# 乌鲁木齐 20 20200121 iloop= 14
# It worked
# 乌鲁木齐 20 20200121 iloop= 15
# It worked
# 乌鲁木齐 20 20200121 iloop= 16
# It worked
# 乌鲁木齐 20 20200121 iloop= 17
# It worked
# 乌鲁木齐 20 20200121 iloop= 18
# It worked
# 乌鲁木齐 20 20200121 iloop= 19
# It worked
# 乌鲁木齐 20 20200121 iloop= 20
# It worked
# 乌鲁木齐 20 20200121 iloop= 21
# It worked
# 乌鲁木齐 20 20200121 iloop= 22
# It worked
# 乌鲁木齐 20 20200121 iloop= 23
# It worked
# 乌鲁木齐 20 20200121 iloop= 24
# It worked
# 乌鲁木齐 20 20200121 iloop= 25
# It worked
# 乌鲁木齐 20 20200121 iloop= 26
# It worked
# 乌鲁木齐 20 20200121 iloop= 27
# It worked
# 乌鲁木齐 20 20200121 iloop= 28
# It worked
# 乌鲁木齐 20 20200121 iloop= 29
# It worked
# 乌鲁木齐 20 20200121 iloop= 30
# It worked
# 乌鲁木齐 20 20200121 iloop= 31
# It worked
# 乌鲁木齐 20 20200121 iloop= 32
# It worked
# 乌鲁木齐 20 20200121 iloop= 33
# It worked
# 乌鲁木齐 20 20200121 iloop= 34
# It worked
# 乌鲁木齐 20 20200121 iloop= 35
# It worked
# 乌鲁木齐 20 20200121 iloop= 36
# It worked
# 乌鲁木齐 20 20200121 iloop= 37
# It worked
# 乌鲁木齐 20 20200121 iloop= 38
# It worked
# 乌鲁木齐 20 20200121 iloop= 39
# It worked
# 乌鲁木齐 20 20200121 iloop= 40
# It worked
# 乌鲁木齐 20 20200121 iloop= 41
# It worked
# 乌鲁木齐 20 20200121 iloop= 42
# It worked
# 乌鲁木齐 20 20200121 iloop= 43
# It worked
# 乌鲁木齐 20 20200121 iloop= 44
# It worked
# 乌鲁木齐 20 20200121 iloop= 45
# It worked
# 乌鲁木齐 20 20200121 iloop= 46
# It worked
# 乌鲁木齐 20 20200121 iloop= 47
# It worked
# 乌鲁木齐 20 20200121 iloop= 48
# It worked
# 乌鲁木齐 20 20200121 iloop= 49
# It worked
# 乌鲁木齐 20 20200121 iloop= 50
# It worked
# 那曲 20 20200121 iloop= 1
# It worked
# 巢湖 21 20200122 oloop= 1
# It worked
# 阳江 21 20200122 oloop= 1
# It worked
# 乌鲁木齐 21 20200122 oloop= 1
# It worked
# 青岛 21 20200122 oloop= 1
# It worked
# 大庆 21 20200122 oloop= 1
# It worked
# 那曲 21 20200122 oloop= 1
# It worked
# 楚雄州 21 20200122 oloop= 1
# It worked
# 酒泉 21 20200122 oloop= 1
# It worked
# 神农架地区 21 20200122 oloop= 1
# It worked
# 韶关 21 20200122 oloop= 1
# It worked
# 巢湖 21 20200122 iloop= 1
# It worked
# 阳江 21 20200122 iloop= 1
# It worked
# 乌鲁木齐 21 20200122 iloop= 1
# It worked
# 青岛 21 20200122 iloop= 1
# It worked
# 大庆 21 20200122 iloop= 1
# It worked
# 那曲 21 20200122 iloop= 1
# It worked
# 楚雄州 21 20200122 iloop= 1
# It worked
# 酒泉 21 20200122 iloop= 1
# It worked
# 神农架地区 21 20200122 iloop= 1
# It worked
# 韶关 21 20200122 iloop= 1
# It worked
# 五家渠 22 20200123 oloop= 1
# It worked
# 巢湖 22 20200123 oloop= 1
# It worked
# 石河子 22 20200123 oloop= 1
# It worked
# 哈密 22 20200123 oloop= 1
# It worked
# 图木舒克 22 20200123 oloop= 1
# It worked
# 秦皇岛 22 20200123 oloop= 1
# It worked
# 那曲 22 20200123 oloop= 1
# It worked
# 楚雄州 22 20200123 oloop= 1
# It worked
# 神农架地区 22 20200123 oloop= 1
# It worked
# 五家渠 22 20200123 iloop= 1
# It worked
# 巢湖 22 20200123 iloop= 1
# It worked
# 石河子 22 20200123 iloop= 1
# It worked
# 哈密 22 20200123 iloop= 1
# It worked
# 图木舒克 22 20200123 iloop= 1
# It worked
# 秦皇岛 22 20200123 iloop= 1
# It worked
# 那曲 22 20200123 iloop= 1
# It worked
# 楚雄州 22 20200123 iloop= 1
# It worked
# 神农架地区 22 20200123 iloop= 1
# It worked
# 济南 23 20200124 oloop= 1
# It worked
# 巢湖 23 20200124 oloop= 1
# It worked
# 乌鲁木齐 23 20200124 oloop= 1
# It worked
# 南充 23 20200124 oloop= 1
# It worked
# 济南 23 20200124 iloop= 1
# It worked
# 巢湖 23 20200124 iloop= 1
# It worked
# 乌鲁木齐 23 20200124 iloop= 1
# It worked
# 南充 23 20200124 iloop= 1
# It worked
# 昌吉州 24 20200125 oloop= 1
# It worked
# 兰州 24 20200125 oloop= 1
# It worked
# 巢湖 24 20200125 oloop= 1

# %%
with open('mo.txt', 'wb') as f:
    pickle.dump(dout, f)

with open('mi.txt', 'wb') as f:
    pickle.dump(din, f)

#
ddinli = copy.deepcopy(ddinli2)
ddoutli = copy.deepcopy(ddoutli2)
